# %% [markdown]
# # Machine learning Fundamentals

# %%
print('What is machine learning');

# q: What is machine learning?
# a:
# Out:
# What is machine learning

# %% [markdown]
# # pandas example

# %%
# installing pandas in jypyter notebook
# !pip install pandas

# installing matplotlib
# !pip install matplotlib

# installing seaborn
# !pip install seaborn

# %%
# importing pandas library
import pandas as pd
# defining url from where data needs to be loaded (data is present as csv)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv";
# loading data into dataframe
# DataFrame - data frame is a bi-dimentional data structure, similar to a table
# with rows and columns. One of the most common python lib to handle such type of structure is
# Pandas
df  = pd.read_csv(url)

# %%
# printing first 5 rows in data set

df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
# One of the most popular python library for data visualization is 'Matplotlib'

# Let's visualize the distribution of the penguins species with a bar plot in matplotlib

import matplotlib.pyplot as plt
df['species'].value_counts().plot(kind='bar')
plt.show()

# %%
# let's visualize with boxplots how the flipper length, bill length and bill depth are distributed
# among various species (relationship with flipper lenght, bill length and bill depth) with species

# Seaborn - A library built upan matplotlib

import seaborn as sns
sns.boxplot(x='species', y='flipper_length_mm', data=df)
plt.show()
sns.boxplot(x='species', y='bill_length_mm', data=df)
plt.show()
sns.boxplot(x='species', y='bill_depth_mm', data=df)
plt.show()

# %%
# Preparing the data for building model

# 1. Handle missing values (Data for which at least one property is not available in csv)
# co: Show rows with missing values 
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []

# %%
# co: drop rows with missing values
df = df.dropna()
